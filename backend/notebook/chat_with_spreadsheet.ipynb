# %% [markdown]
# ### Chat With Multiple CSV

# %%
# Take csv or excel sheet & upload data in sqlite3
# Take User questions
# Parse questions & get relevant tables and columns
# Get Unique noun
# Generate SQL query
# Validate SQL Query if something wrong fix it
# Execute SQL
#     If there is no error & SQL Query is relevent
#         Choose visualization
#         format data for visualization
#     Else
#         Format result

# %%
# from langchain_community.llms import Ollama
# llm = Ollama(model="llama3.1:latest")
from langchain_groq import ChatGroq

llm = ChatGroq(groq_api_key="", model="gemma2-9b-it")

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

# %%
## Insert data in sequalite
import os
import pandas as pd
from sqlalchemy import create_engine

# Function to read CSV/Excel and insert into SQLite database
def insert_data_to_sqlite(file_path):
    # Extract the file name without extension to use as table name
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    
    # Read the data (change this to pd.read_excel() for Excel files)
    data = pd.read_csv(file_path)

    # Create a SQLite database (or connect if it already exists)
    engine = create_engine('sqlite:///lumin.db')
    
    # Insert data into the SQLite database with the table name as the file name
    data.to_sql(file_name, con=engine, if_exists='replace', index=False)
    print(f"Data from {file_path} has been inserted into the '{file_name}' table in the 'lumin.db' database.")

# %%
# Specify the path to your CSV/Excel file
ecom_data = [
  "olist_customers_dataset.csv",
  "olist_geolocation_dataset.csv",
  "olist_order_items_dataset.csv",
  "olist_order_payments_dataset.csv",
  "olist_order_reviews_dataset.csv",
  "olist_orders_dataset.csv",
  "olist_products_dataset.csv",
  "olist_sellers_dataset.csv",
  "product_category_name_translation.csv"
]

# for data in ecom_data:
#     file_path = ("./ecommerce/{data}".format(data=data))
#     # print(file_path)
#     insert_data_to_sqlite(file_path)

# %%
from sqlalchemy import inspect
from typing import List, Dict

# Assuming you have an SQLAlchemy engine created
engine = create_engine('sqlite:///lumin.db')  

def get_schemas(table_names: List[str]) -> List[Dict]:
    try:
        # Create an inspector object
        inspector = inspect(engine)

        # Initialize an array to hold the schema information for all tables
        schemas_info = []

        for table_name in table_names:
            schema_info = {
                "table_name": table_name,
                "schema": []
            }

            # Get the columns for the specified table
            columns = inspector.get_columns(table_name)

            # Collect column information
            for column in columns:
                schema_info["schema"].append({
                    "name": column['name'],
                    "type": str(column['type']),
                    "nullable": column['nullable']
                })

            # Append the schema information for the current table to the list
            schemas_info.append(schema_info)

        # Return the schema information for all tables
        return schemas_info

    except Exception as e:
        print(f"An error occurred: {e}")
        return []  # Return an empty list in case of an error

schema = get_schemas(['olist_products_dataset',"olist_orders_dataset","olist_customers_dataset","olist_order_items_dataset"])

print(schema)
# Out:
# [{'table_name': 'olist_products_dataset', 'schema': [{'name': 'product_id', 'type': 'TEXT', 'nullable': True}, {'name': 'product_category_name', 'type': 'TEXT', 'nullable': True}, {'name': 'product_name_lenght', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_description_lenght', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_photos_qty', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_weight_g', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_length_cm', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_height_cm', 'type': 'FLOAT', 'nullable': True}, {'name': 'product_width_cm', 'type': 'FLOAT', 'nullable': True}]}, {'table_name': 'olist_orders_dataset', 'schema': [{'name': 'order_id', 'type': 'TEXT', 'nullable': True}, {'name': 'customer_id', 'type': 'TEXT', 'nullable': True}, {'name': 'order_status', 'type': 'TEXT', 'nullable': True}, {'name': 'order_purchase_timestamp', 'type': 'TEXT', 'nullable': True}, {'name': 'order_approved_at', 'type': 'TEXT', 'nullable': True}, {'name': 'order_delivered_carrier_date', 'type': 'TEXT', 'nullable': True}, {'name': 'order_delivered_customer_date', 'type': 'TEXT', 'nullable': True}, {'name': 'order_estimated_delivery_date', 'type': 'TEXT', 'nullable': True}]}, {'table_name': 'olist_customers_dataset', 'schema': [{'name': 'customer_id', 'type': 'TEXT', 'nullable': True}, {'name': 'customer_unique_id', 'type': 'TEXT', 'nullable': True}, {'name': 'customer_zip_code_prefix', 'type': 'BIGINT', 'nullable': True}, {'name': 'customer_city', 'type': 'TEXT', 'nullable': True}, {'name': 'customer_state', 'type': 'TEXT', 'nullable': True}]}, {'table_name': 'olist_order_items_dataset', 'schema': [{'name': 'order_id', 'type': 'TEXT', 'nullable': True}, {'name': 'order_item_id', 'type': 'BIGINT', 'nullable': True}, {'name': 'product_id', 'type': 'TEXT', 'nullable': True}, {'name': 'seller_id', 'type': 'TEXT', 'nullable': True}, {'name': 'shipping_limit_date', 'type': 'TEXT', 'nullable': True}, {'name': 'price', 'type': 'FLOAT', 'nullable': True}, {'name': 'freight_value', 'type': 'FLOAT', 'nullable': True}]}]

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import text  # Import text for raw SQL queries
from typing import List, Dict, Any

# Assuming you have an SQLAlchemy engine created
engine = create_engine('sqlite:///lumin.db')  # Example for SQLite

# Create a session factory bound to the engine
Session = sessionmaker(bind=engine)

def execute_query(query: str) -> List[Any]:
    try:
        # Create a new session
        with Session() as session:  # Call Session() without any parameters
            # Use a text() construct for the query
            result = session.execute(text(query))  # Use text() for raw SQL
            # If the query is a SELECT statement, fetch the results
            if result.returns_rows:
                return [row for row in result.fetchall()]  # Convert RowProxy to dict
            else:
                # For non-SELECT queries, commit the transaction and return an empty list
                session.commit()
                return []

    except Exception as e:
        print(f"An error occurred: {e}")
        return []  # Return an empty list in case of an error

# %%
execute_query("SELECT * FROM results;")
# Out:
# [('1872-11-30', 'Scotland', 'England', 0, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1873-03-08', 'England', 'Scotland', 4, 2, 'Friendly', 'London', 'England', 0),
#  ('1874-03-07', 'Scotland', 'England', 2, 1, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1875-03-06', 'England', 'Scotland', 2, 2, 'Friendly', 'London', 'England', 0),
#  ('1876-03-04', 'Scotland', 'England', 3, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1876-03-25', 'Scotland', 'Wales', 4, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1877-03-03', 'England', 'Scotland', 1, 3, 'Friendly', 'London', 'England', 0),
#  ('1877-03-05', 'Wales', 'Scotland', 0, 2, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1878-03-02', 'Scotland', 'England', 7, 2, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1878-03-23', 'Scotland', 'Wales', 9, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1879-01-18', 'England', 'Wales', 2, 1, 'Friendly', 'London', 'England', 0),
#  ('1879-04-05', 'England', 'Scotland', 5, 4, 'Friendly', 'London', 'England', 0),
#  ('1879-04-07', 'Wales', 'Scotland', 0, 3, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1880-03-13', 'Scotland', 'England', 5, 4, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1880-03-15', 'Wales', 'England', 2, 3, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1880-03-27', 'Scotland', 'Wales', 5, 1, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1881-02-26', 'England', 'Wales', 0, 1, 'Friendly', 'Blackburn', 'England', 0),
#  ('1881-03-12', 'England', 'Scotland', 1, 6, 'Friendly', 'London', 'England', 0),
#  ('1881-03-14', 'Wales', 'Scotland', 1, 5, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1882-02-18', 'Northern Ireland', 'England', 0, 13, 'Friendly', 'Belfast', 'Ireland', 0),
#  ('1882-02-25', 'Wales', 'Northern Ireland', 7, 1, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1882-03-11', 'Scotland', 'England', 5, 1, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1882-03-13', 'Wales', 'England', 5, 3, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1882-03-25', 'Scotland', 'Wales', 5, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1883-02-03', 'England', 'Wales', 5, 0, 'Friendly', 'London', 'England', 0),
#  ('1883-02-24', 'England', 'Northern Ireland', 7, 0, 'Friendly', 'Liverpool', 'England', 0),
#  ('1883-03-10', 'England', 'Scotland', 2, 3, 'Friendly', 'Sheffield', 'England', 0),
#  ('1883-03-12', 'Wales', 'Scotland', 0, 3, 'Friendly', 'Wrexham', 'Wales', 0),
#  ('1883-03-17', 'Northern Ireland', 'Wales', 1, 1, 'Friendly', 'Belfast', 'Ireland', 0),
#  ('1884-01-26', 'Northern Ireland', 'Scotland', 0, 5, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1884-02-09', 'Wales', 'Northern Ireland', 6, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1884-02-23', 'Northern Ireland', 'England', 1, 8, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1884-03-15', 'Scotland', 'England', 1, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1884-03-17', 'Wales', 'England', 0, 4, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1884-03-29', 'Scotland', 'Wales', 4, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1885-02-28', 'England', 'Northern Ireland', 4, 0, 'British Home Championship', 'Manchester', 'England', 0),
#  ('1885-03-14', 'England', 'Wales', 1, 1, 'British Home Championship', 'Blackburn', 'England', 0),
#  ('1885-03-14', 'Scotland', 'Northern Ireland', 8, 2, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1885-03-21', 'England', 'Scotland', 1, 1, 'British Home Championship', 'London', 'England', 0),
#  ('1885-03-23', 'Wales', 'Scotland', 1, 8, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1885-04-11', 'Northern Ireland', 'Wales', 2, 8, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1885-11-28', 'United States', 'Canada', 0, 1, 'Friendly', 'Newark', 'United States', 0),
#  ('1886-02-27', 'Wales', 'Northern Ireland', 5, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1886-03-13', 'Northern Ireland', 'England', 1, 6, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1886-03-20', 'Northern Ireland', 'Scotland', 2, 7, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1886-03-27', 'Scotland', 'England', 1, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1886-03-29', 'Wales', 'England', 1, 3, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1886-04-10', 'Scotland', 'Wales', 4, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1886-11-25', 'United States', 'Canada', 3, 2, 'Friendly', 'Newark', 'United States', 0),
#  ('1887-02-05', 'England', 'Northern Ireland', 7, 0, 'British Home Championship', 'Sheffield', 'England', 0),
#  ('1887-02-19', 'Scotland', 'Northern Ireland', 4, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1887-02-26', 'England', 'Wales', 4, 0, 'British Home Championship', 'London', 'England', 0),
#  ('1887-03-12', 'Northern Ireland', 'Wales', 4, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1887-03-19', 'England', 'Scotland', 2, 3, 'British Home Championship', 'Blackburn', 'England', 0),
#  ('1887-03-21', 'Wales', 'Scotland', 0, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1888-02-04', 'England', 'Wales', 5, 1, 'British Home Championship', 'Crewe', 'England', 0),
#  ('1888-03-03', 'Wales', 'Northern Ireland', 11, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1888-03-10', 'Scotland', 'Wales', 5, 1, 'British Home Championship', 'Edinburgh', 'Scotland', 0),
#  ('1888-03-17', 'Scotland', 'England', 0, 5, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1888-03-24', 'Northern Ireland', 'Scotland', 2, 10, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1888-04-07', 'Northern Ireland', 'England', 1, 5, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1888-09-19', 'Scotland', 'Canada', 4, 0, 'Friendly', 'Glasgow', 'Scotland', 0),
#  ('1889-02-23', 'England', 'Wales', 4, 1, 'British Home Championship', 'Stoke-on-Trent', 'England', 0),
#  ('1889-03-02', 'England', 'Northern Ireland', 6, 1, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1889-03-09', 'Scotland', 'Northern Ireland', 7, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1889-04-13', 'England', 'Scotland', 2, 3, 'British Home Championship', 'London', 'England', 0),
#  ('1889-04-15', 'Wales', 'Scotland', 0, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1889-04-27', 'Northern Ireland', 'Wales', 1, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1890-02-08', 'Wales', 'Northern Ireland', 5, 2, 'British Home Championship', 'Shrewsbury', 'England', 1),
#  ('1890-03-15', 'Northern Ireland', 'England', 1, 9, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1890-03-15', 'Wales', 'England', 1, 3, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1890-03-22', 'Scotland', 'Wales', 5, 0, 'British Home Championship', 'Paisley', 'Scotland', 0),
#  ('1890-03-29', 'Northern Ireland', 'Scotland', 1, 4, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1890-04-05', 'Scotland', 'England', 1, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1891-02-07', 'Northern Ireland', 'Wales', 7, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1891-03-07', 'England', 'Wales', 4, 1, 'British Home Championship', 'Sunderland', 'England', 0),
#  ('1891-03-07', 'England', 'Northern Ireland', 6, 1, 'British Home Championship', 'Wolverhampton', 'England', 0),
#  ('1891-03-21', 'Wales', 'Scotland', 3, 4, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1891-03-28', 'Scotland', 'Northern Ireland', 2, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1891-04-06', 'England', 'Scotland', 2, 1, 'British Home Championship', 'Blackburn', 'England', 0),
#  ('1892-02-27', 'Wales', 'Northern Ireland', 1, 1, 'British Home Championship', 'Bangor', 'Wales', 0),
#  ('1892-03-05', 'Northern Ireland', 'England', 0, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1892-03-05', 'Wales', 'England', 0, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1892-03-19', 'Northern Ireland', 'Scotland', 2, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1892-03-26', 'Scotland', 'Wales', 6, 1, 'British Home Championship', 'Edinburgh', 'Scotland', 0),
#  ('1892-04-02', 'Scotland', 'England', 1, 4, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1893-02-25', 'England', 'Northern Ireland', 6, 1, 'British Home Championship', 'Birmingham', 'England', 0),
#  ('1893-03-13', 'England', 'Wales', 6, 0, 'British Home Championship', 'Stoke-on-Trent', 'England', 0),
#  ('1893-03-18', 'Wales', 'Scotland', 0, 8, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1893-03-25', 'Scotland', 'Northern Ireland', 6, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1893-04-01', 'England', 'Scotland', 5, 2, 'British Home Championship', 'Richmond', 'England', 0),
#  ('1894-02-24', 'Wales', 'Northern Ireland', 4, 1, 'British Home Championship', 'Swansea', 'Wales', 0),
#  ('1894-03-03', 'Northern Ireland', 'England', 2, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1894-03-12', 'Wales', 'England', 1, 5, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1894-03-24', 'Scotland', 'Wales', 5, 2, 'British Home Championship', 'Kilmarnock', 'Scotland', 0),
#  ('1894-03-31', 'Northern Ireland', 'Scotland', 1, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1894-04-07', 'Scotland', 'England', 2, 2, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1895-03-09', 'England', 'Northern Ireland', 9, 0, 'British Home Championship', 'Derby', 'England', 0),
#  ('1895-03-16', 'Northern Ireland', 'Wales', 2, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1895-03-18', 'England', 'Wales', 1, 1, 'British Home Championship', 'London', 'England', 0),
#  ('1895-03-23', 'Wales', 'Scotland', 2, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1895-03-30', 'Scotland', 'Northern Ireland', 3, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1895-04-06', 'England', 'Scotland', 3, 0, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1896-02-29', 'Wales', 'Northern Ireland', 6, 1, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1896-03-07', 'Northern Ireland', 'England', 0, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1896-03-16', 'Wales', 'England', 1, 9, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1896-03-21', 'Scotland', 'Wales', 4, 0, 'British Home Championship', 'Dundee', 'Scotland', 0),
#  ('1896-03-28', 'Northern Ireland', 'Scotland', 3, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1896-04-04', 'Scotland', 'England', 2, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1897-02-20', 'England', 'Northern Ireland', 6, 0, 'British Home Championship', 'Nottingham', 'England', 0),
#  ('1897-03-06', 'Northern Ireland', 'Wales', 4, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1897-03-20', 'Wales', 'Scotland', 2, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1897-03-27', 'Scotland', 'Northern Ireland', 5, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1897-03-29', 'England', 'Wales', 4, 0, 'British Home Championship', 'Sheffield', 'England', 0),
#  ('1897-04-03', 'England', 'Scotland', 1, 2, 'British Home Championship', 'London', 'England', 0),
#  ('1898-02-19', 'Wales', 'Northern Ireland', 0, 1, 'British Home Championship', 'Llandudno', 'Wales', 0),
#  ('1898-03-05', 'Northern Ireland', 'England', 2, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1898-03-19', 'Scotland', 'Wales', 5, 2, 'British Home Championship', 'Motherwell', 'Scotland', 0),
#  ('1898-03-26', 'Northern Ireland', 'Scotland', 0, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1898-03-28', 'Wales', 'England', 0, 3, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1898-04-02', 'Scotland', 'England', 1, 3, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1899-02-18', 'England', 'Northern Ireland', 13, 2, 'British Home Championship', 'Sunderland', 'England', 0),
#  ('1899-03-04', 'Northern Ireland', 'Wales', 1, 0, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1899-03-18', 'Wales', 'Scotland', 0, 6, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1899-03-20', 'England', 'Wales', 4, 0, 'British Home Championship', 'Bristol', 'England', 0),
#  ('1899-03-25', 'Scotland', 'Northern Ireland', 9, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1899-04-08', 'England', 'Scotland', 2, 1, 'British Home Championship', 'Birmingham', 'England', 0),
#  ('1900-02-03', 'Scotland', 'Wales', 5, 2, 'British Home Championship', 'Aberdeen', 'Scotland', 0),
#  ('1900-02-24', 'Wales', 'Northern Ireland', 2, 0, 'British Home Championship', 'Llandudno', 'Wales', 0),
#  ('1900-03-03', 'Northern Ireland', 'Scotland', 0, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1900-03-17', 'Northern Ireland', 'England', 0, 2, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1900-03-26', 'Wales', 'England', 1, 1, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1900-04-07', 'Scotland', 'England', 4, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1901-02-23', 'Scotland', 'Northern Ireland', 11, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1901-03-02', 'Wales', 'Scotland', 1, 1, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1901-03-09', 'England', 'Northern Ireland', 3, 0, 'British Home Championship', 'Southampton', 'England', 0),
#  ('1901-03-18', 'England', 'Wales', 6, 0, 'British Home Championship', 'Newcastle', 'England', 0),
#  ('1901-03-23', 'Northern Ireland', 'Wales', 0, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1901-03-30', 'England', 'Scotland', 2, 2, 'British Home Championship', 'London', 'England', 0),
#  ('1902-02-22', 'Wales', 'Northern Ireland', 0, 3, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1902-03-01', 'Northern Ireland', 'Scotland', 1, 5, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1902-03-03', 'Wales', 'England', 0, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1902-03-15', 'Scotland', 'Wales', 5, 1, 'British Home Championship', 'Greenock', 'Scotland', 0),
#  ('1902-03-22', 'Northern Ireland', 'England', 0, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1902-05-03', 'England', 'Scotland', 2, 2, 'British Home Championship', 'Birmingham', 'England', 0),
#  ('1902-07-20', 'Uruguay', 'Argentina', 0, 6, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1902-10-12', 'Austria', 'Hungary', 5, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1903-02-14', 'England', 'Northern Ireland', 4, 0, 'British Home Championship', 'Wolverhampton', 'England', 0),
#  ('1903-03-02', 'England', 'Wales', 2, 1, 'British Home Championship', 'Portsmouth', 'England', 0),
#  ('1903-03-09', 'Wales', 'Scotland', 0, 1, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1903-03-21', 'Scotland', 'Northern Ireland', 0, 2, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1903-03-28', 'Northern Ireland', 'Wales', 2, 0, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1903-04-04', 'England', 'Scotland', 1, 2, 'British Home Championship', 'Sheffield', 'England', 0),
#  ('1903-04-05', 'Hungary', 'Czechoslovakia', 2, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1903-06-11', 'Hungary', 'Austria', 3, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1903-09-13', 'Argentina', 'Uruguay', 2, 3, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1903-10-11', 'Austria', 'Hungary', 4, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1904-02-29', 'Wales', 'England', 2, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1904-03-12', 'Northern Ireland', 'England', 1, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1904-03-12', 'Scotland', 'Wales', 1, 1, 'British Home Championship', 'Dundee', 'Scotland', 0),
#  ('1904-03-21', 'Wales', 'Northern Ireland', 0, 1, 'British Home Championship', 'Bangor', 'Wales', 0),
#  ('1904-03-26', 'Northern Ireland', 'Scotland', 1, 1, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1904-04-09', 'Scotland', 'England', 0, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1904-05-01', 'Belgium', 'France', 3, 3, 'Évence Coppée Trophy', 'Brussels', 'Belgium', 0),
#  ('1904-06-02', 'Hungary', 'Austria', 3, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1904-10-09', 'Austria', 'Hungary', 5, 4, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1905-02-12', 'France', 'Switzerland', 1, 0, 'Friendly', 'Paris', 'France', 0),
#  ('1905-02-25', 'England', 'Northern Ireland', 1, 1, 'British Home Championship', 'Middlesbrough', 'England', 0),
#  ('1905-03-06', 'Wales', 'Scotland', 3, 1, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1905-03-18', 'Scotland', 'Northern Ireland', 4, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1905-03-27', 'England', 'Wales', 3, 1, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1905-04-01', 'England', 'Scotland', 1, 0, 'British Home Championship', 'London', 'England', 0),
#  ('1905-04-08', 'Northern Ireland', 'Wales', 2, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1905-04-09', 'Hungary', 'Austria', 0, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1905-04-17', 'Guernsey', 'Alderney', 6, 0, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1905-04-27', 'Jersey', 'Guernsey', 0, 1, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1905-04-30', 'Belgium', 'Netherlands', 1, 4, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1905-05-07', 'Belgium', 'France', 7, 0, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1905-05-14', 'Netherlands', 'Belgium', 4, 0, 'Friendly', 'Rotterdam', 'Netherlands', 0),
#  ('1905-08-15', 'Argentina', 'Uruguay', 0, 0, 'Copa Lipton', 'Buenos Aires', 'Argentina', 0),
#  ('1906-02-17', 'Northern Ireland', 'England', 0, 5, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1906-03-03', 'Scotland', 'Wales', 0, 2, 'British Home Championship', 'Edinburgh', 'Scotland', 0),
#  ('1906-03-17', 'Northern Ireland', 'Scotland', 0, 1, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1906-03-19', 'Wales', 'England', 0, 1, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1906-03-29', 'Jersey', 'Guernsey', 1, 2, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1906-04-01', 'Hungary', 'Czechoslovakia', 1, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1906-04-02', 'Wales', 'Northern Ireland', 4, 4, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1906-04-02', 'Guernsey', 'Alderney', 1, 0, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1906-04-07', 'Scotland', 'England', 2, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1906-04-22', 'France', 'Belgium', 0, 5, 'Friendly', 'Saint-Cloud', 'France', 0),
#  ('1906-04-29', 'Belgium', 'Netherlands', 5, 0, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1906-05-13', 'Netherlands', 'Belgium', 2, 3, 'Friendly', 'Rotterdam', 'Netherlands', 0),
#  ('1906-08-15', 'Uruguay', 'Argentina', 0, 2, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1906-10-07', 'Czechoslovakia', 'Hungary', 4, 4, 'Friendly', 'Prague', 'Bohemia', 0),
#  ('1906-10-21', 'Argentina', 'Uruguay', 2, 1, 'Copa Newton', 'Buenos Aires', 'Argentina', 0),
#  ('1906-11-04', 'Hungary', 'Austria', 3, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1907-02-16', 'England', 'Northern Ireland', 1, 0, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1907-02-23', 'Northern Ireland', 'Wales', 2, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1907-03-04', 'Wales', 'Scotland', 1, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1907-03-16', 'Scotland', 'Northern Ireland', 3, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1907-03-18', 'England', 'Wales', 1, 1, 'British Home Championship', 'London', 'England', 0),
#  ('1907-03-21', 'Alderney', 'Jersey', 1, 2, 'Muratti Vase', 'Guernsey', 'Guernsey', 1),
#  ('1907-04-04', 'Jersey', 'Guernsey', 2, 3, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1907-04-06', 'England', 'Scotland', 1, 1, 'British Home Championship', 'Newcastle', 'England', 0),
#  ('1907-04-07', 'Hungary', 'Czechoslovakia', 5, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1907-04-14', 'Belgium', 'Netherlands', 1, 3, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1907-04-21', 'Belgium', 'France', 1, 2, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1907-05-05', 'Austria', 'Hungary', 3, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1907-05-09', 'Netherlands', 'Belgium', 1, 2, 'Friendly', 'Haarlem', 'Netherlands', 0),
#  ('1907-10-06', 'Czechoslovakia', 'Hungary', 5, 3, 'Friendly', 'Prague', 'Bohemia', 0),
#  ('1907-11-03', 'Hungary', 'Austria', 4, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1908-02-15', 'Northern Ireland', 'England', 1, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1908-03-07', 'Scotland', 'Wales', 2, 1, 'British Home Championship', 'Dundee', 'Scotland', 0),
#  ('1908-03-08', 'Switzerland', 'France', 1, 2, 'Friendly', 'Geneva', 'Switzerland', 0),
#  ('1908-03-14', 'Northern Ireland', 'Scotland', 0, 5, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1908-03-16', 'Wales', 'England', 1, 7, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1908-03-29', 'Belgium', 'Netherlands', 1, 4, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1908-04-02', 'Guernsey', 'Alderney', 3, 0, 'Muratti Vase', 'Jersey', 'Jersey', 1),
#  ('1908-04-04', 'Scotland', 'England', 1, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1908-04-05', 'Hungary', 'Czechoslovakia', 5, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1908-04-05', 'Switzerland', 'Germany', 5, 3, 'Friendly', 'Basel', 'Switzerland', 0),
#  ('1908-04-09', 'Guernsey', 'Jersey', 0, 4, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1908-04-11', 'Wales', 'Northern Ireland', 0, 1, 'British Home Championship', 'Aberdare', 'Wales', 0),
#  ('1908-04-12', 'France', 'Belgium', 1, 2, 'Friendly', 'Colombes', 'France', 0),
#  ('1908-04-26', 'Netherlands', 'Belgium', 3, 1, 'Friendly', 'Rotterdam', 'Netherlands', 0),
#  ('1908-05-03', 'Austria', 'Hungary', 4, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1908-05-10', 'Netherlands', 'France', 4, 1, 'Friendly', 'Rotterdam', 'Netherlands', 0),
#  ('1908-06-06', 'Austria', 'England', 1, 6, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1908-06-07', 'Austria', 'Germany', 3, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1908-06-08', 'Austria', 'England', 1, 11, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1908-06-10', 'Hungary', 'England', 0, 7, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1908-06-13', 'Czechoslovakia', 'England', 0, 4, 'Friendly', 'Prague', 'Bohemia', 0),
#  ('1908-07-12', 'Sweden', 'Norway', 11, 3, 'Friendly', 'Gothenburg', 'Sweden', 0),
#  ('1908-08-15', 'Uruguay', 'Argentina', 2, 2, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1908-09-13', 'Argentina', 'Uruguay', 2, 1, 'Copa Newton', 'Buenos Aires', 'Argentina', 0),
#  ('1908-10-04', 'Argentina', 'Uruguay', 0, 1, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1908-10-25', 'Netherlands', 'Sweden', 5, 3, 'Friendly', 'The Hague', 'Netherlands', 0),
#  ('1908-10-26', 'Belgium', 'Sweden', 2, 1, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1908-11-01', 'Hungary', 'Austria', 5, 3, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1909-02-13', 'England', 'Northern Ireland', 4, 0, 'British Home Championship', 'Bradford', 'England', 0),
#  ('1909-03-01', 'Wales', 'Scotland', 3, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1909-03-15', 'England', 'Wales', 2, 0, 'British Home Championship', 'Nottingham', 'England', 0),
#  ('1909-03-15', 'Scotland', 'Northern Ireland', 5, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1909-03-18', 'Guernsey', 'Jersey', 3, 0, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1909-03-20', 'Northern Ireland', 'Wales', 2, 3, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1909-03-21', 'Belgium', 'Netherlands', 1, 4, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1909-03-25', 'Guernsey', 'Alderney', 2, 0, 'Muratti Vase', 'Jersey', 'Jersey', 1),
#  ('1909-04-03', 'England', 'Scotland', 2, 0, 'British Home Championship', 'London', 'England', 0),
#  ('1909-04-04', 'Germany', 'Switzerland', 1, 0, 'Friendly', 'Karlsruhe', 'Germany', 0),
#  ('1909-04-04', 'Hungary', 'Germany', 3, 3, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1909-04-25', 'Netherlands', 'Belgium', 4, 1, 'Friendly', 'Rotterdam', 'Netherlands', 0),
#  ('1909-05-02', 'Austria', 'Hungary', 3, 4, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1909-05-09', 'Belgium', 'France', 5, 2, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1909-05-29', 'Hungary', 'England', 2, 4, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1909-05-30', 'Hungary', 'Austria', 1, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1909-05-31', 'Hungary', 'England', 2, 8, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1909-06-01', 'Austria', 'England', 1, 8, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1909-08-15', 'Argentina', 'Uruguay', 2, 1, 'Copa Lipton', 'Buenos Aires', 'Argentina', 0),
#  ('1909-09-19', 'Uruguay', 'Argentina', 2, 2, 'Copa Newton', 'Montevideo', 'Uruguay', 0),
#  ('1909-10-10', 'Argentina', 'Uruguay', 3, 1, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1909-11-07', 'Hungary', 'Austria', 2, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1910-02-12', 'Northern Ireland', 'England', 1, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1910-03-05', 'Scotland', 'Wales', 1, 0, 'British Home Championship', 'Kilmarnock', 'Scotland', 0),
#  ('1910-03-13', 'Belgium', 'Netherlands', 3, 2, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1910-03-14', 'Wales', 'England', 0, 1, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1910-03-19', 'Northern Ireland', 'Scotland', 1, 0, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1910-04-02', 'Scotland', 'England', 2, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1910-04-03', 'France', 'Belgium', 0, 4, 'Friendly', 'Gentilly', 'France', 0),
#  ('1910-04-03', 'Switzerland', 'Germany', 2, 3, 'Friendly', 'Basel', 'Switzerland', 0),
#  ('1910-04-07', 'Jersey', 'Alderney', 7, 1, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1910-04-10', 'Netherlands', 'Belgium', 7, 0, 'Friendly', 'Haarlem', 'Netherlands', 0),
#  ('1910-04-11', 'Wales', 'Northern Ireland', 4, 1, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1910-04-21', 'Guernsey', 'Jersey', 2, 3, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1910-04-24', 'Netherlands', 'Germany', 4, 2, 'Friendly', 'Arnhem', 'Netherlands', 0),
#  ('1910-05-01', 'Austria', 'Hungary', 2, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1910-05-15', 'Italy', 'France', 6, 2, 'Friendly', 'Milan', 'Italy', 0),
#  ('1910-05-16', 'Germany', 'Belgium', 0, 3, 'Friendly', 'Duisburg', 'Germany', 0),
#  ('1910-05-26', 'Hungary', 'Italy', 6, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1910-05-27', 'Argentina', 'Chile', 3, 1, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1910-05-29', 'Chile', 'Uruguay', 0, 3, 'Friendly', 'Buenos Aires', 'Argentina', 1),
#  ('1910-06-05', 'Argentina', 'Chile', 5, 1, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1910-06-12', 'Argentina', 'Uruguay', 4, 1, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1910-08-15', 'Uruguay', 'Argentina', 3, 1, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1910-09-11', 'Chile', 'Argentina', 0, 3, 'Friendly', 'Viña del Mar', 'Chile', 0),
#  ('1910-09-11', 'Norway', 'Sweden', 0, 4, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1910-10-16', 'Germany', 'Netherlands', 1, 2, 'Friendly', 'Kleve', 'Germany', 0),
#  ('1910-11-06', 'Hungary', 'Austria', 3, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1910-11-13', 'Argentina', 'Uruguay', 1, 1, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1910-11-27', 'Argentina', 'Uruguay', 2, 6, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1911-01-01', 'France', 'Hungary', 0, 3, 'Friendly', 'Maisons-Alfort', 'France', 0),
#  ('1911-01-06', 'Italy', 'Hungary', 0, 1, 'Friendly', 'Milan', 'Italy', 0),
#  ('1911-01-08', 'Switzerland', 'Hungary', 2, 0, 'Friendly', 'Zürich', 'Switzerland', 0),
#  ('1911-01-28', 'Northern Ireland', 'Wales', 1, 2, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1911-02-11', 'England', 'Northern Ireland', 2, 1, 'British Home Championship', 'Derby', 'England', 0),
#  ('1911-03-06', 'Wales', 'Scotland', 2, 2, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1911-03-13', 'England', 'Wales', 3, 0, 'British Home Championship', 'London', 'England', 0),
#  ('1911-03-18', 'Scotland', 'Northern Ireland', 2, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1911-03-19', 'Belgium', 'Netherlands', 1, 5, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1911-03-26', 'Germany', 'Switzerland', 6, 2, 'Friendly', 'Stuttgart', 'Germany', 0),
#  ('1911-04-01', 'England', 'Scotland', 1, 1, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1911-04-02', 'Netherlands', 'Belgium', 3, 1, 'Friendly', 'Dordrecht', 'Netherlands', 0),
#  ('1911-04-09', 'France', 'Italy', 2, 2, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1911-04-20', 'Guernsey', 'Alderney', 2, 1, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1911-04-23', 'Belgium', 'Germany', 2, 1, 'Friendly', 'Liège', 'Belgium', 0),
#  ('1911-04-23', 'Switzerland', 'France', 5, 2, 'Friendly', 'Geneva', 'Switzerland', 0),
#  ('1911-04-27', 'Jersey', 'Guernsey', 4, 1, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1911-04-30', 'Belgium', 'France', 7, 1, 'Friendly', 'Uccle', 'Belgium', 0),
#  ('1911-05-07', 'Austria', 'Hungary', 3, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1911-05-07', 'Italy', 'Switzerland', 2, 2, 'Friendly', 'Milan', 'Italy', 0),
#  ('1911-05-21', 'Switzerland', 'Italy', 3, 0, 'Friendly', 'La Chaux-de-Fonds', 'Switzerland', 0),
#  ('1911-06-18', 'Sweden', 'Germany', 2, 4, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1911-08-15', 'Argentina', 'Uruguay', 0, 2, 'Copa Lipton', 'Buenos Aires', 'Argentina', 0),
#  ('1911-09-17', 'Sweden', 'Norway', 4, 1, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1911-09-17', 'Uruguay', 'Argentina', 2, 3, 'Copa Newton', 'Montevideo', 'Uruguay', 0),
#  ('1911-10-08', 'Uruguay', 'Argentina', 1, 1, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1911-10-09', 'Germany', 'Austria', 1, 2, 'Friendly', 'Dresden', 'Germany', 0),
#  ('1911-10-22', 'Argentina', 'Uruguay', 2, 0, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1911-10-22', 'Finland', 'Sweden', 2, 5, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1911-10-29', 'Germany', 'Sweden', 1, 3, 'Friendly', 'Hamburg', 'Germany', 0),
#  ('1911-10-29', 'Hungary', 'Switzerland', 9, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1911-10-29', 'Luxembourg', 'France', 1, 4, 'Friendly', 'Luxembourg', 'Luxembourg', 0),
#  ('1911-10-29', 'Uruguay', 'Argentina', 3, 0, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1911-11-05', 'Hungary', 'Austria', 2, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1911-12-17', 'Germany', 'Hungary', 1, 4, 'Friendly', 'Munich', 'Germany', 0),
#  ('1912-01-28', 'France', 'Belgium', 1, 1, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1912-02-10', 'Northern Ireland', 'England', 1, 6, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1912-02-10', 'France', 'Catalonia', 7, 0, 'Friendly', 'Paris', 'France', 0),
#  ('1912-02-18', 'France', 'Switzerland', 4, 1, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1912-02-20', 'Belgium', 'Switzerland', 9, 2, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1912-03-02', 'Scotland', 'Wales', 1, 0, 'British Home Championship', 'Edinburgh', 'Scotland', 0),
#  ('1912-03-10', 'Belgium', 'Netherlands', 1, 2, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1912-03-11', 'Wales', 'England', 0, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1912-03-16', 'Northern Ireland', 'Scotland', 1, 4, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1912-03-17', 'Italy', 'France', 3, 4, 'Friendly', 'Turin', 'Italy', 0),
#  ('1912-03-23', 'Scotland', 'England', 1, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1912-03-24', 'Netherlands', 'Germany', 5, 5, 'Friendly', 'Zwolle', 'Netherlands', 0),
#  ('1912-04-13', 'Wales', 'Northern Ireland', 2, 3, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1912-04-14', 'Hungary', 'Germany', 4, 4, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1912-04-18', 'Jersey', 'Guernsey', 3, 3, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1912-04-19', 'Jersey', 'Guernsey', 2, 5, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1912-04-25', 'Guernsey', 'Alderney', 4, 0, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1912-04-28', 'Netherlands', 'Belgium', 4, 3, 'Friendly', 'Dordrecht', 'Netherlands', 0),
#  ('1912-05-05', 'Austria', 'Hungary', 1, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1912-05-05', 'Switzerland', 'Germany', 1, 2, 'Friendly', 'St. Gallen', 'Switzerland', 0),
#  ('1912-06-16', 'Norway', 'Sweden', 1, 2, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1912-06-20', 'Sweden', 'Hungary', 2, 2, 'Friendly', 'Gothenburg', 'Sweden', 0),
#  ('1912-06-23', 'Norway', 'Hungary', 0, 6, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1912-06-27', 'Sweden', 'Finland', 7, 1, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1912-06-30', 'Austria', 'Italy', 5, 1, 'Friendly', 'Stockholm', 'Sweden', 1),
#  ('1912-07-01', 'Austria', 'Norway', 1, 1, 'Friendly', 'Stockholm', 'Sweden', 1),
#  ('1912-07-03', 'Hungary', 'Austria', 3, 0, 'Friendly', 'Stockholm', 'Sweden', 1),
#  ('1912-07-03', 'Norway', 'Russia', 2, 1, 'Friendly', 'Stockholm', 'Sweden', 1),
#  ('1912-07-05', 'Netherlands', 'Austria', 3, 1, 'Friendly', 'Stockholm', 'Sweden', 1),
#  ('1912-07-12', 'Russia', 'Hungary', 0, 9, 'Friendly', 'Moscow', 'Russia', 0),
#  ('1912-07-14', 'Russia', 'Hungary', 0, 12, 'Friendly', 'Moscow', 'Russia', 0),
#  ('1912-08-15', 'Uruguay', 'Argentina', 2, 0, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1912-08-25', 'Uruguay', 'Argentina', 3, 0, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1912-09-22', 'Argentina', 'Uruguay', 0, 1, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1912-10-06', 'Argentina', 'Uruguay', 3, 3, 'Copa Newton', 'Avellaneda', 'Argentina', 0),
#  ('1912-10-06', 'Denmark', 'Germany', 3, 1, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1912-11-03', 'Hungary', 'Austria', 4, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1912-11-03', 'Sweden', 'Norway', 4, 2, 'Friendly', 'Gothenburg', 'Sweden', 0),
#  ('1912-11-17', 'Germany', 'Netherlands', 2, 3, 'Friendly', 'Leipzig', 'Germany', 0),
#  ('1912-12-01', 'Uruguay', 'Argentina', 1, 3, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1912-12-01', 'Catalonia', 'France', 1, 0, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1912-12-22', 'Italy', 'Austria', 1, 3, 'Friendly', 'Genoa', 'Italy', 0),
#  ('1913-01-12', 'France', 'Italy', 1, 0, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1913-01-18', 'Northern Ireland', 'Wales', 0, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1913-02-04', 'Philippines', 'China PR', 2, 1, 'Far Eastern Championship Games', 'Manila', 'Philippines', 0),
#  ('1913-02-15', 'Northern Ireland', 'England', 2, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1913-02-16', 'Belgium', 'France', 3, 0, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1913-03-03', 'Wales', 'Scotland', 0, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1913-03-09', 'Belgium', 'Netherlands', 3, 3, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1913-03-09', 'Switzerland', 'France', 1, 4, 'Friendly', 'Geneva', 'Switzerland', 0),
#  ('1913-03-15', 'Northern Ireland', 'Scotland', 1, 2, 'British Home Championship', 'Dublin', 'Ireland', 0),
#  ('1913-03-17', 'England', 'Wales', 4, 3, 'British Home Championship', 'Bristol', 'England', 0),
#  ('1913-04-03', 'Jersey', 'Alderney', 5, 2, 'Muratti Vase', 'Guernsey', 'Guernsey', 1),
#  ('1913-04-05', 'England', 'Scotland', 1, 0, 'British Home Championship', 'London', 'England', 0),
#  ('1913-04-17', 'Jersey', 'Guernsey', 2, 4, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1913-04-20', 'France', 'Luxembourg', 8, 0, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1913-04-20', 'Netherlands', 'Belgium', 2, 4, 'Friendly', 'Zwolle', 'Netherlands', 0),
#  ('1913-04-27', 'Austria', 'Hungary', 1, 4, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1913-05-01', 'Italy', 'Belgium', 1, 0, 'Friendly', 'Turin', 'Italy', 0),
#  ('1913-05-04', 'Russia', 'Sweden', 1, 4, 'Friendly', 'Moscow', 'Russia', 0),
#  ('1913-05-04', 'Switzerland', 'Belgium', 1, 2, 'Friendly', 'Basel', 'Switzerland', 0),
#  ('1913-05-18', 'Germany', 'Switzerland', 1, 2, 'Friendly', 'Freiburg', 'Germany', 0),
#  ('1913-05-18', 'Hungary', 'Sweden', 2, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1913-05-25', 'Denmark', 'Sweden', 8, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1913-06-08', 'Sweden', 'Norway', 9, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1913-06-15', 'Argentina', 'Uruguay', 1, 1, 'Friendly', 'Avellaneda', 'Argentina', 0),
#  ('1913-06-15', 'Austria', 'Italy', 2, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1913-07-09', 'Argentina', 'Uruguay', 2, 1, 'Friendly', 'Avellaneda', 'Argentina', 0),
#  ('1913-08-15', 'Argentina', 'Uruguay', 4, 0, 'Copa Lipton', 'Avellaneda', 'Argentina', 0),
#  ('1913-08-31', 'Argentina', 'Uruguay', 2, 0, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1913-09-14', 'Russia', 'Norway', 1, 1, 'Friendly', 'Moscow', 'Russia', 0),
#  ('1913-09-21', 'Chile', 'Argentina', 0, 2, 'Friendly', 'Viña del Mar', 'Chile', 0),
#  ('1913-10-05', 'Sweden', 'Denmark', 0, 10, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1913-10-05', 'Uruguay', 'Argentina', 1, 0, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1913-10-26', 'Germany', 'Denmark', 1, 4, 'Friendly', 'Hamburg', 'Germany', 0),
#  ('1913-10-26', 'Hungary', 'Austria', 4, 3, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1913-10-26', 'Norway', 'Sweden', 1, 1, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1913-10-26', 'Uruguay', 'Argentina', 1, 0, 'Copa Newton', 'Montevideo', 'Uruguay', 0),
#  ('1913-11-02', 'Belgium', 'Switzerland', 2, 0, 'Friendly', 'Verviers', 'Belgium', 0),
#  ('1913-11-23', 'Belgium', 'Germany', 6, 2, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1914-01-11', 'Italy', 'Austria', 0, 0, 'Friendly', 'Milan', 'Italy', 0),
#  ('1914-01-19', 'Wales', 'Northern Ireland', 1, 2, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1914-01-25', 'France', 'Belgium', 4, 3, 'Friendly', 'Lille', 'France', 0),
#  ('1914-02-08', 'Luxembourg', 'France', 5, 4, 'Friendly', 'Luxembourg', 'Luxembourg', 0),
#  ('1914-02-14', 'England', 'Northern Ireland', 0, 3, 'British Home Championship', 'Middlesbrough', 'England', 0),
#  ('1914-02-28', 'Scotland', 'Wales', 0, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1914-03-08', 'France', 'Switzerland', 2, 2, 'Friendly', 'Saint-Ouen', 'France', 0),
#  ('1914-03-14', 'Northern Ireland', 'Scotland', 1, 1, 'British Home Championship', 'Belfast', 'Ireland', 0),
#  ('1914-03-15', 'Belgium', 'Netherlands', 2, 4, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1914-03-16', 'Wales', 'England', 0, 2, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1914-03-29', 'Italy', 'France', 2, 0, 'Friendly', 'Turin', 'Italy', 0),
#  ('1914-04-02', 'Guernsey', 'Alderney', 4, 0, 'Muratti Vase', 'Jersey', 'Jersey', 1),
#  ('1914-04-05', 'Italy', 'Switzerland', 1, 1, 'Friendly', 'Genoa', 'Italy', 0),
#  ('1914-04-05', 'Netherlands', 'Germany', 4, 4, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1914-04-14', 'Scotland', 'England', 3, 1, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1914-04-23', 'Guernsey', 'Jersey', 2, 1, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1914-04-26', 'Netherlands', 'Belgium', 4, 2, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1914-05-03', 'Austria', 'Hungary', 2, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1914-05-17', 'Denmark', 'Netherlands', 4, 3, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1914-05-17', 'Switzerland', 'Italy', 0, 1, 'Friendly', 'Berne', 'Switzerland', 0),
#  ('1914-05-24', 'Sweden', 'Finland', 4, 3, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1914-05-31', 'Hungary', 'France', 5, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1914-06-21', 'Sweden', 'Hungary', 1, 1, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1914-06-28', 'Norway', 'Sweden', 0, 1, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1914-07-05', 'Sweden', 'Russia', 2, 2, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1914-07-12', 'Norway', 'Russia', 1, 1, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1914-08-30', 'Uruguay', 'Argentina', 3, 2, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1914-09-13', 'Argentina', 'Uruguay', 2, 1, 'Copa Premio Honor Argentino', 'Buenos Aires', 'Argentina', 0),
#  ('1914-09-20', 'Argentina', 'Brazil', 3, 0, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1914-09-27', 'Argentina', 'Brazil', 0, 1, 'Copa Roca', 'Buenos Aires', 'Argentina', 0),
#  ('1914-10-04', 'Hungary', 'Austria', 2, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1914-10-25', 'Sweden', 'Norway', 7, 0, 'Friendly', 'Solna', 'Sweden', 0),
#  ('1914-11-08', 'Austria', 'Hungary', 1, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1915-01-03', 'Basque Country', 'Catalonia', 6, 1, 'Friendly', 'Bilbao', 'Spain', 0),
#  ('1915-01-31', 'Italy', 'Switzerland', 3, 1, 'Friendly', 'Turin', 'Italy', 0),
#  ('1915-02-07', 'Catalonia', 'Basque Country', 2, 2, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1915-05-02', 'Hungary', 'Austria', 2, 5, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1915-05-13', 'Basque Country', 'Catalonia', 1, 0, 'Friendly', 'Madrid', 'Spain', 0),
#  ('1915-05-18', 'China PR', 'Philippines', 0, 0, 'Far Eastern Championship Games', 'Shanghai', 'China PR', 0),
#  ('1915-05-19', 'China PR', 'Philippines', 1, 0, 'Far Eastern Championship Games', 'Shanghai', 'China PR', 0),
#  ('1915-05-30', 'Austria', 'Hungary', 1, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1915-06-06', 'Denmark', 'Sweden', 2, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1915-06-27', 'Norway', 'Sweden', 1, 1, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1915-07-18', 'Uruguay', 'Argentina', 2, 3, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1915-08-15', 'Argentina', 'Uruguay', 2, 1, 'Copa Lipton', 'Buenos Aires', 'Argentina', 0),
#  ('1915-09-12', 'Uruguay', 'Argentina', 2, 0, 'Copa Newton', 'Montevideo', 'Uruguay', 0),
#  ('1915-09-19', 'Denmark', 'Norway', 8, 1, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1915-10-03', 'Austria', 'Hungary', 4, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1915-10-24', 'Sweden', 'Norway', 5, 2, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1915-10-31', 'Sweden', 'Denmark', 0, 2, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1915-11-07', 'Hungary', 'Austria', 6, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1916-05-07', 'Austria', 'Hungary', 3, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1916-05-21', 'Catalonia', 'Basque Country', 1, 3, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1916-05-22', 'Catalonia', 'Basque Country', 0, 0, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1916-06-04', 'Denmark', 'Sweden', 2, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1916-06-04', 'Hungary', 'Austria', 2, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1916-06-04', 'Basque Country', 'Catalonia', 5, 0, 'Friendly', 'Bilbao', 'Spain', 0),
#  ('1916-06-25', 'Norway', 'Denmark', 0, 2, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1916-07-02', 'Chile', 'Uruguay', 0, 4, 'Copa América', 'Buenos Aires', 'Argentina', 1),
#  ('1916-07-02', 'Sweden', 'Norway', 6, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1916-07-06', 'Argentina', 'Chile', 6, 1, 'Copa América', 'Buenos Aires', 'Argentina', 0),
#  ('1916-07-08', 'Brazil', 'Chile', 1, 1, 'Copa América', 'Buenos Aires', 'Argentina', 1),
#  ('1916-07-10', 'Argentina', 'Brazil', 1, 1, 'Copa América', 'Buenos Aires', 'Argentina', 0),
#  ('1916-07-12', 'Argentina', 'Chile', 1, 0, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1916-07-12', 'Brazil', 'Uruguay', 1, 2, 'Copa América', 'Buenos Aires', 'Argentina', 1),
#  ('1916-07-14', 'Uruguay', 'Chile', 4, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1916-07-17', 'Argentina', 'Uruguay', 0, 0, 'Copa América', 'Avellaneda', 'Argentina', 0),
#  ('1916-07-18', 'Uruguay', 'Brazil', 0, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1916-08-15', 'Argentina', 'Uruguay', 3, 1, 'Copa Newton', 'Avellaneda', 'Argentina', 0),
#  ('1916-08-15', 'Uruguay', 'Argentina', 1, 2, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1916-08-20', 'Sweden', 'United States', 2, 3, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1916-09-03', 'Norway', 'United States', 1, 1, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1916-10-01', 'Argentina', 'Uruguay', 7, 2, 'Friendly', 'Avellaneda', 'Argentina', 0),
#  ('1916-10-01', 'Hungary', 'Austria', 2, 3, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1916-10-01', 'Norway', 'Sweden', 0, 0, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1916-10-01', 'Uruguay', 'Argentina', 0, 1, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1916-10-08', 'Sweden', 'Denmark', 4, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1916-10-15', 'Denmark', 'Norway', 8, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1916-10-29', 'Uruguay', 'Argentina', 3, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1916-11-05', 'Austria', 'Hungary', 3, 3, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1917-05-06', 'Austria', 'Hungary', 1, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1917-05-07', 'Japan', 'Philippines', 2, 15, 'Friendly', 'Tokyo', 'Japan', 0),
#  ('1917-05-09', 'Japan', 'China PR', 0, 5, 'Far Eastern Championship Games', 'Tokyo', 'Japan', 0),
#  ('1917-05-10', 'Japan', 'Philippines', 2, 15, 'Far Eastern Championship Games', 'Tokyo', 'Japan', 0),
#  ('1917-05-11', 'China PR', 'Philippines', 3, 0, 'Far Eastern Championship Games', 'Tokyo', 'Japan', 1),
#  ('1917-06-03', 'Denmark', 'Sweden', 1, 1, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1917-06-03', 'Hungary', 'Austria', 6, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1917-06-17', 'Norway', 'Denmark', 1, 2, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1917-07-15', 'Austria', 'Hungary', 1, 4, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1917-07-18', 'Uruguay', 'Argentina', 0, 2, 'Copa Premio Honor Uruguayo', 'Montevideo', 'Uruguay', 0),
#  ('1917-08-15', 'Argentina', 'Uruguay', 1, 0, 'Copa Lipton', 'Avellaneda', 'Argentina', 0),
#  ('1917-08-19', 'Sweden', 'Norway', 3, 3, 'Friendly', 'Helsingborg', 'Sweden', 0),
#  ('1917-09-02', 'Uruguay', 'Argentina', 1, 0, 'Copa Newton', 'Montevideo', 'Uruguay', 0),
#  ('1917-09-16', 'Norway', 'Sweden', 0, 2, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1917-09-30', 'Uruguay', 'Chile', 4, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1917-10-03', 'Argentina', 'Brazil', 4, 2, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1917-10-06', 'Argentina', 'Chile', 1, 0, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1917-10-07', 'Denmark', 'Norway', 12, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1917-10-07', 'Hungary', 'Austria', 2, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1917-10-07', 'Uruguay', 'Brazil', 4, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1917-10-12', 'Brazil', 'Chile', 5, 0, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1917-10-14', 'Sweden', 'Denmark', 1, 2, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1917-10-14', 'Uruguay', 'Argentina', 1, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1917-10-16', 'Uruguay', 'Brazil', 3, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1917-11-04', 'Austria', 'Hungary', 1, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1917-12-23', 'Switzerland', 'Austria', 0, 1, 'Friendly', 'Basel', 'Switzerland', 0),
#  ('1917-12-26', 'Switzerland', 'Austria', 3, 2, 'Friendly', 'Zürich', 'Switzerland', 0),
#  ('1918-04-14', 'Hungary', 'Austria', 2, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1918-05-09', 'Austria', 'Switzerland', 5, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1918-05-12', 'Hungary', 'Switzerland', 2, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1918-05-26', 'Sweden', 'Norway', 2, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1918-06-02', 'Austria', 'Hungary', 0, 2, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1918-06-02', 'Denmark', 'Sweden', 3, 0, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1918-06-16', 'Norway', 'Denmark', 3, 1, 'Friendly', 'Kristiania', 'Norway', 0),
# ...
#  ('1923-11-25', 'Central Spain', 'Galicia', 1, 0, 'Friendly', 'Madrid', 'Spain', 0),
#  ('1923-12-02', 'Argentina', 'Brazil', 0, 2, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1923-12-02', 'Uruguay', 'Argentina', 2, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1923-12-09', 'Argentina', 'Brazil', 2, 0, 'Copa Roca', 'Buenos Aires', 'Argentina', 0),
#  ('1923-12-09', 'Mexico', 'Guatemala', 2, 1, 'Friendly', 'Mexico City', 'Mexico', 0),
#  ('1923-12-12', 'Mexico', 'Guatemala', 2, 0, 'Friendly', 'Mexico City', 'Mexico', 0),
#  ('1923-12-16', 'Mexico', 'Guatemala', 3, 3, 'Friendly', 'Mexico City', 'Mexico', 0),
#  ('1923-12-16', 'Spain', 'Portugal', 3, 0, 'Friendly', 'Seville', 'Spain', 0),
#  ('1924-01-13', 'France', 'Belgium', 2, 0, 'Friendly', 'Montrouge', 'France', 0),
#  ('1924-01-13', 'Germany', 'Austria', 4, 3, 'Friendly', 'Nuremberg', 'Germany', 0),
#  ('1924-01-20', 'Italy', 'Austria', 0, 4, 'Friendly', 'Genoa', 'Italy', 0),
#  ('1924-02-10', 'Yugoslavia', 'Austria', 1, 4, 'Friendly', 'Zagreb', 'Yugoslavia', 0),
#  ('1924-02-16', 'Wales', 'Scotland', 2, 0, 'British Home Championship', 'Cardiff', 'Wales', 0),
#  ('1924-03-01', 'Scotland', 'Northern Ireland', 2, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1924-03-03', 'England', 'Wales', 1, 2, 'British Home Championship', 'Blackburn', 'England', 0),
#  ('1924-03-09', 'Italy', 'Spain', 0, 0, 'Friendly', 'Milan', 'Italy', 0),
#  ('1924-03-13', 'Catalonia', 'Spain', 0, 7, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1924-03-15', 'Northern Ireland', 'Wales', 0, 1, 'British Home Championship', 'Belfast', 'Northern Ireland', 0),
#  ('1924-03-23', 'Netherlands', 'Belgium', 1, 1, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1924-03-23', 'Switzerland', 'France', 3, 0, 'Friendly', 'Geneva', 'Switzerland', 0),
#  ('1924-03-23', 'Brittany', 'Luxembourg', 1, 1, 'Friendly', 'Rennes', 'France', 0),
#  ('1924-04-06', 'Aruba', 'Curaçao', 0, 4, 'Friendly', 'Oranjestad', 'Aruba', 0),
#  ('1924-04-06', 'Hungary', 'Italy', 7, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1924-04-10', 'Jersey', 'Alderney', 1, 0, 'Muratti Vase', 'Guernsey', 'Guernsey', 1),
#  ('1924-04-12', 'England', 'Scotland', 1, 1, 'British Home Championship', 'London', 'England', 0),
#  ('1924-04-21', 'Netherlands', 'Germany', 0, 1, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1924-04-21', 'Switzerland', 'Denmark', 2, 0, 'Friendly', 'Basel', 'Switzerland', 0),
#  ('1924-04-21', 'Guernsey', 'Alderney', 1, 2, 'Peace Cup', 'Guernsey', 'Guernsey', 0),
#  ('1924-04-27', 'Belgium', 'Netherlands', 1, 1, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1924-05-01', 'Jersey', 'Guernsey', 1, 0, 'Muratti Vase', 'Jersey', 'Jersey', 0),
#  ('1924-05-04', 'Hungary', 'Austria', 2, 2, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1924-05-15', 'Paraguay', 'Argentina', 1, 3, 'Copa Chevallier Boutell', 'Asunción', 'Paraguay', 0),
#  ('1924-05-17', 'France', 'England', 1, 3, 'Friendly', 'Vincennes', 'France', 0),
#  ('1924-05-18', 'Paraguay', 'Argentina', 2, 1, 'Copa Chevallier Boutell', 'Asunción', 'Paraguay', 0),
#  ('1924-05-18', 'Sweden', 'Poland', 5, 1, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1924-05-18', 'Switzerland', 'Hungary', 4, 2, 'Friendly', 'Zürich', 'Switzerland', 0),
#  ('1924-05-20', 'Austria', 'Romania', 4, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1924-05-21', 'Austria', 'Bulgaria', 6, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1924-05-25', 'Argentina', 'Uruguay', 4, 0, 'Copa Newton', 'Buenos Aires', 'Argentina', 0),
#  ('1924-05-25', 'Uruguay', 'Argentina', 2, 0, 'Copa Lipton', 'Montevideo', 'Uruguay', 0),
#  ('1924-05-25', 'Italy', 'Spain', 1, 0, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-05-25', 'Czechoslovakia', 'Turkey', 5, 2, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-25', 'Switzerland', 'Lithuania', 9, 0, 'Olympic Games', 'Vincennes', 'France', 1),
#  ('1924-05-25', 'United States', 'Estonia', 1, 0, 'Olympic Games', 'Vincennes', 'France', 1),
#  ('1924-05-26', 'Uruguay', 'Yugoslavia', 7, 0, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-05-26', 'Hungary', 'Poland', 5, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-27', 'Egypt', 'Lithuania', 10, 0, 'Friendly', 'Vincennes', 'France', 1),
#  ('1924-05-27', 'France', 'Latvia', 7, 0, 'Olympic Games', 'Paris', 'France', 0),
#  ('1924-05-27', 'Netherlands', 'Romania', 6, 0, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-05-28', 'Switzerland', 'Czechoslovakia', 1, 1, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-28', 'Republic of Ireland', 'Bulgaria', 1, 0, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-05-29', 'Italy', 'Luxembourg', 2, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-29', 'Sweden', 'Belgium', 8, 1, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-05-29', 'Egypt', 'Hungary', 3, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-29', 'Uruguay', 'United States', 3, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-05-30', 'Switzerland', 'Czechoslovakia', 1, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-06-01', 'France', 'Uruguay', 1, 5, 'Olympic Games', 'Colombes', 'France', 0),
#  ('1924-06-01', 'Sweden', 'Egypt', 5, 0, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-06-02', 'Switzerland', 'Italy', 2, 1, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-06-02', 'Netherlands', 'Republic of Ireland', 2, 1, 'Olympic Games', 'Paris', 'France', 1),
#  ('1924-06-04', 'France', 'Hungary', 0, 1, 'Friendly', 'Le Havre', 'France', 0),
#  ('1924-06-05', 'Switzerland', 'Sweden', 2, 1, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-06-06', 'Uruguay', 'Netherlands', 2, 1, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-06-07', 'Australia', 'Canada', 3, 2, 'Friendly', 'Brisbane', 'Australia', 0),
#  ('1924-06-08', 'Sweden', 'Netherlands', 1, 1, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-06-09', 'Sweden', 'Netherlands', 3, 1, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-06-09', 'Uruguay', 'Switzerland', 3, 0, 'Olympic Games', 'Colombes', 'France', 1),
#  ('1924-06-10', 'Poland', 'United States', 2, 3, 'Friendly', 'Warsaw', 'Poland', 0),
#  ('1924-06-14', 'Australia', 'Canada', 0, 1, 'Friendly', 'Sydney', 'Australia', 0),
#  ('1924-06-15', 'Denmark', 'Sweden', 2, 3, 'Nordic Championship', 'Copenhagen', 'Denmark', 0),
#  ('1924-06-15', 'Norway', 'Germany', 0, 2, 'Friendly', 'Kristiania', 'Norway', 0),
#  ('1924-06-15', 'Catalonia', 'Basque Country', 1, 2, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1924-06-17', 'Finland', 'Turkey', 2, 4, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1924-06-19', 'Estonia', 'Turkey', 1, 4, 'Friendly', 'Tallinn', 'Estonia', 0),
#  ('1924-06-22', 'Austria', 'Egypt', 3, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1924-06-22', 'Latvia', 'Turkey', 1, 3, 'Friendly', 'Riga', 'Latvia', 0),
#  ('1924-06-23', 'Australia', 'Canada', 4, 1, 'Friendly', 'Sydney', 'Australia', 0),
#  ('1924-06-28', 'Australia', 'Canada', 0, 0, 'Friendly', 'Newcastle', 'Australia', 0),
#  ('1924-06-29', 'Poland', 'Turkey', 2, 0, 'Friendly', 'Łódź', 'Poland', 0),
#  ('1924-06-29', 'Sweden', 'Egypt', 5, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1924-07-12', 'Australia', 'Canada', 1, 4, 'Friendly', 'Adelaide', 'Australia', 0),
#  ('1924-07-25', 'Sweden', 'Estonia', 5, 2, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1924-07-26', 'Australia', 'Canada', 1, 0, 'Friendly', 'Sydney', 'Australia', 0),
#  ('1924-07-28', 'Finland', 'Sweden', 5, 7, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1924-08-10', 'Poland', 'Finland', 1, 0, 'Friendly', 'Warsaw', 'Poland', 0),
#  ('1924-08-14', 'Latvia', 'Finland', 0, 2, 'Friendly', 'Riga', 'Latvia', 0),
#  ('1924-08-23', 'Finland', 'Norway', 2, 0, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1924-08-24', 'Estonia', 'Lithuania', 1, 2, 'Friendly', 'Tallinn', 'Estonia', 0),
#  ('1924-08-31', 'Czechoslovakia', 'Romania', 4, 1, 'Friendly', 'Prague', 'Czechoslovakia', 0),
#  ('1924-08-31', 'Germany', 'Sweden', 1, 4, 'Friendly', 'Berlin', 'Germany', 0),
#  ('1924-08-31', 'Hungary', 'Poland', 4, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1924-09-14', 'Austria', 'Hungary', 2, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1924-09-14', 'Finland', 'Estonia', 4, 0, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1924-09-14', 'Norway', 'Denmark', 1, 3, 'Nordic Championship', 'Kristiania', 'Norway', 0),
#  ('1924-09-21', 'Hungary', 'Germany', 4, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1924-09-21', 'Sweden', 'Norway', 6, 1, 'Nordic Championship', 'Solna', 'Sweden', 0),
#  ('1924-09-21', 'Uruguay', 'Argentina', 1, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1924-09-24', 'Northern Ireland', 'South Africa', 1, 2, 'Friendly', 'Belfast', 'Northern Ireland', 0),
#  ('1924-09-28', 'Yugoslavia', 'Czechoslovakia', 0, 2, 'Friendly', 'Zagreb', 'Yugoslavia', 0),
#  ('1924-10-02', 'Argentina', 'Uruguay', 2, 1, 'Friendly', 'Buenos Aires', 'Argentina', 0),
#  ('1924-10-05', 'Denmark', 'Belgium', 2, 1, 'Friendly', 'Copenhagen', 'Denmark', 0),
#  ('1924-10-12', 'Argentina', 'Paraguay', 0, 0, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1924-10-18', 'Latvia', 'Estonia', 2, 0, 'Friendly', 'Riga', 'Latvia', 0),
#  ('1924-10-19', 'Uruguay', 'Chile', 5, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1924-10-22', 'England', 'Northern Ireland', 3, 1, 'British Home Championship', 'Liverpool', 'England', 0),
#  ('1924-10-25', 'Argentina', 'Chile', 2, 0, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1924-10-26', 'Uruguay', 'Paraguay', 3, 1, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1924-11-01', 'Chile', 'Paraguay', 1, 3, 'Copa América', 'Montevideo', 'Uruguay', 1),
#  ('1924-11-02', 'Netherlands', 'South Africa', 2, 1, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1924-11-02', 'Uruguay', 'Argentina', 0, 0, 'Copa América', 'Montevideo', 'Uruguay', 0),
#  ('1924-11-09', 'Austria', 'Sweden', 1, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1924-11-11', 'Belgium', 'France', 3, 0, 'Friendly', 'Brussels', 'Belgium', 0),
#  ('1924-11-16', 'Italy', 'Sweden', 2, 2, 'Friendly', 'Milan', 'Italy', 0),
#  ('1924-11-16', 'Russia', 'Turkey', 3, 0, 'Friendly', 'Moscow', 'Soviet Union', 0),
#  ('1924-11-23', 'Germany', 'Italy', 0, 1, 'Friendly', 'Duisburg', 'Germany', 0),
#  ('1924-12-08', 'England', 'Belgium', 4, 0, 'Friendly', 'West Bromwich', 'England', 0),
#  ('1924-12-14', 'Germany', 'Switzerland', 1, 1, 'Friendly', 'Stuttgart', 'Germany', 0),
#  ('1924-12-21', 'Spain', 'Austria', 2, 1, 'Friendly', 'Barcelona', 'Spain', 0),
#  ('1925-02-14', 'Scotland', 'Wales', 3, 1, 'British Home Championship', 'Edinburgh', 'Scotland', 0),
#  ('1925-02-22', 'Luxembourg', 'Brittany', 1, 1, 'Friendly', 'Luxembourg', 'Luxembourg', 0),
#  ('1925-02-28', 'Northern Ireland', 'Scotland', 0, 3, 'British Home Championship', 'Belfast', 'Northern Ireland', 0),
#  ('1925-02-28', 'Wales', 'England', 1, 2, 'British Home Championship', 'Swansea', 'Wales', 0),
#  ('1925-03-12', 'Guernsey', 'Alderney', 3, 0, 'Peace Cup', 'Guernsey', 'Guernsey', 0),
#  ('1925-03-15', 'Belgium', 'Netherlands', 0, 1, 'Friendly', 'Antwerp', 'Belgium', 0),
#  ('1925-03-22', 'Austria', 'Switzerland', 2, 0, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1925-03-22', 'Haiti', 'Jamaica', 1, 2, 'Friendly', 'Port-au-Prince', 'Haiti', 0),
#  ('1925-03-22', 'Italy', 'France', 7, 0, 'Friendly', 'Turin', 'Italy', 0),
#  ('1925-03-25', 'Hungary', 'Switzerland', 5, 0, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1925-03-26', 'Haiti', 'Jamaica', 0, 3, 'Friendly', 'Port-au-Prince', 'Haiti', 0),
#  ('1925-03-29', 'Haiti', 'Jamaica', 0, 1, 'Friendly', 'Port-au-Prince', 'Haiti', 0),
#  ('1925-03-29', 'Netherlands', 'Germany', 2, 1, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1925-04-02', 'Guernsey', 'Alderney', 3, 0, 'Muratti Vase', 'Jersey', 'Jersey', 1),
#  ('1925-04-04', 'Scotland', 'England', 2, 0, 'British Home Championship', 'Glasgow', 'Scotland', 0),
#  ('1925-04-10', 'Turkey', 'Bulgaria', 2, 1, 'Friendly', 'Istanbul', 'Turkey', 0),
#  ('1925-04-18', 'Wales', 'Northern Ireland', 0, 0, 'British Home Championship', 'Wrexham', 'Wales', 0),
#  ('1925-04-19', 'France', 'Austria', 0, 4, 'Friendly', 'Vincennes', 'France', 0),
#  ('1925-04-19', 'Switzerland', 'Netherlands', 4, 1, 'Friendly', 'Zürich', 'Switzerland', 0),
#  ('1925-04-30', 'Guernsey', 'Jersey', 2, 1, 'Muratti Vase', 'Guernsey', 'Guernsey', 0),
#  ('1925-05-01', 'Romania', 'Turkey', 1, 2, 'Friendly', 'Bucharest', 'Romania', 0),
#  ('1925-05-03', 'Netherlands', 'Belgium', 5, 0, 'Friendly', 'Amsterdam', 'Netherlands', 0),
#  ('1925-05-05', 'Austria', 'Hungary', 3, 1, 'Friendly', 'Vienna', 'Austria', 0),
#  ('1925-05-15', 'Turkey', 'Russia', 1, 2, 'Friendly', 'Ankara', 'Turkey', 0),
#  ('1925-05-18', 'Philippines', 'Japan', 4, 0, 'Far Eastern Championship Games', 'Manila', 'Philippines', 0),
#  ('1925-05-20', 'China PR', 'Japan', 2, 0, 'Friendly', 'Manila', 'Philippines', 1),
#  ('1925-05-20', 'Japan', 'China PR', 0, 2, 'Far Eastern Championship Games', 'Manila', 'Philippines', 1),
#  ('1925-05-21', 'France', 'England', 2, 3, 'Friendly', 'Colombes', 'France', 0),
#  ('1925-05-21', 'Hungary', 'Belgium', 1, 3, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1925-05-22', 'Philippines', 'China PR', 1, 5, 'Friendly', 'Manila', 'Philippines', 0),
#  ('1925-05-22', 'Philippines', 'China PR', 1, 5, 'Far Eastern Championship Games', 'Manila', 'Philippines', 0),
#  ('1925-05-24', 'Czechoslovakia', 'Austria', 3, 1, 'Friendly', 'Prague', 'Czechoslovakia', 0),
#  ('1925-05-24', 'Switzerland', 'Belgium', 0, 0, 'Friendly', 'Lausanne', 'Switzerland', 0),
#  ('1925-05-31', 'Bulgaria', 'Romania', 2, 4, 'Friendly', 'Sofia', 'Bulgaria', 0),
#  ('1925-06-01', 'Switzerland', 'Spain', 0, 3, 'Friendly', 'Berne', 'Switzerland', 0),
#  ('1925-06-07', 'Norway', 'Finland', 1, 0, 'Friendly', 'Oslo', 'Norway', 0),
#  ('1925-06-09', 'Sweden', 'Finland', 4, 0, 'Friendly', 'Gothenburg', 'Sweden', 0),
#  ('1925-06-14', 'Spain', 'Italy', 1, 0, 'Friendly', 'Valencia', 'Spain', 0),
#  ('1925-06-14', 'Sweden', 'Denmark', 0, 2, 'Nordic Championship', 'Stockholm', 'Sweden', 0),
#  ('1925-06-18', 'Portugal', 'Italy', 1, 0, 'Friendly', 'Lisbon', 'Portugal', 0),
#  ('1925-06-21', 'Denmark', 'Norway', 5, 1, 'Nordic Championship', 'Copenhagen', 'Denmark', 0),
#  ('1925-06-21', 'Sweden', 'Germany', 1, 0, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1925-06-26', 'Finland', 'Germany', 3, 5, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1925-06-27', 'Canada', 'United States', 1, 0, 'Friendly', 'Montreal', 'Canada', 0),
#  ('1925-06-28', 'Lithuania', 'Estonia', 0, 1, 'Friendly', 'Kaunas', 'Lithuania', 0),
#  ('1925-07-05', 'Estonia', 'Finland', 2, 0, 'Friendly', 'Tallinn', 'Estonia', 0),
#  ('1925-07-05', 'Sweden', 'Austria', 2, 4, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1925-07-09', 'Argentina', 'Paraguay', 1, 1, 'Copa Chevallier Boutell', 'Buenos Aires', 'Argentina', 0),
#  ('1925-07-10', 'Finland', 'Austria', 1, 2, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1925-07-12', 'Argentina', 'Paraguay', 1, 1, 'Copa Chevallier Boutell', 'Buenos Aires', 'Argentina', 0),
#  ('1925-07-12', 'Sweden', 'Hungary', 6, 2, 'Friendly', 'Stockholm', 'Sweden', 0),
#  ('1925-07-14', 'Uruguay', 'Paraguay', 0, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1925-07-18', 'Uruguay', 'Paraguay', 0, 1, 'Friendly', 'Montevideo', 'Uruguay', 0),
#  ('1925-07-19', 'Poland', 'Hungary', 0, 2, 'Friendly', 'Kraków', 'Poland', 0),
#  ('1925-08-09', 'Finland', 'Latvia', 3, 1, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1925-08-15', 'Paraguay', 'Uruguay', 1, 0, 'Friendly', 'Asunción', 'Paraguay', 0),
#  ('1925-08-19', 'Paraguay', 'Uruguay', 0, 1, 'Friendly', 'Asunción', 'Paraguay', 0),
#  ('1925-08-23', 'Norway', 'Sweden', 3, 7, 'Nordic Championship', 'Oslo', 'Norway', 0),
#  ('1925-08-23', 'Paraguay', 'Uruguay', 0, 0, 'Friendly', 'Asunción', 'Paraguay', 0),
#  ('1925-08-26', 'Estonia', 'Latvia', 2, 2, 'Friendly', 'Tallinn', 'Estonia', 0),
#  ('1925-08-30', 'Finland', 'Poland', 2, 2, 'Friendly', 'Helsinki', 'Finland', 0),
#  ('1925-09-02', 'Estonia', 'Poland', 0, 0, 'Friendly', 'Tallinn', 'Estonia', 0),
#  ('1925-09-20', 'Hungary', 'Austria', 1, 1, 'Friendly', 'Budapest', 'Hungary', 0),
#  ('1925-09-20', 'Latvia', 'Lithuania', 2, 2, 'Friendly', 'Riga', 'Latvia', 0),
#  ...]

# %%
import json

def simple_json_extraction(content):
    # Find the JSON part
    start = content.find('{')
    end = content.rfind('}') + 1
    
    # Extract and parse the JSON
    json_str = content[start:end]
    parsed_json = json.loads(json_str)
    
    # Return the formatted JSON
    return json.dumps(parsed_json, indent=2)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

def get_parse_question(state: dict) -> dict:

    question = state['question']
    schema = state['schema']

    # print(schema, question)

    # prompt = ChatPromptTemplate.from_messages([
    #     ("system", '''
    # You are an expert data analyst tasked with analyzing SQL databases. Your goal is to interpret user questions, understand the schema provided, and identify relevant tables and columns.

    # Instructions:
    # 1. Based on the user question and the provided database schema, identify the relevant tables and columns.
    # 2. Set "is_relevant" to false if the question doesn't apply to the database or lacks sufficient information for an answer.
    # 3. Focus on columns with meaningful nouns (like names or entities) and exclude columns with non-noun values (e.g., IDs, numerical data).
    # 4. Return the response in the following JSON format:
    # {{
    #     "is_relevant": boolean,
    #     "relevant_tables": [
    #         {{
    #             "table_names": ["string"],
    #             "columns": ["string"],
    #             "noun_columns": ["string"]
    #         }}
    #     ]
    # }}

    # Key Notes:
    # - "noun_columns" should include only noun-based columns relevant to the question (e.g., "Artist name" for "What are the top-selling artists?")
    # - "noun_columns" must **only contain valid column names** from the schema. Do not include noun-based values from the user question unless they match an actual column name in the schema.
    # - Exclude numerical or ID columns that do not represent nouns or entities.
    # - The values in "noun_columns" must match the exact format of the corresponding column names in "columns".
    # - Check the schema if string is not available in it then don't include it in columns or noun_columns, EX: if question contain name as spandan than dont add spandan in columns or noun_columns as it is not a column name its a column value.
    # '''),
    #     ("human", "===Database Schema:\n{schema}\n\n===User Question:\n{question}\n\nIdentify the relevant tables and columns based on the provided information:")
    # ])

    prompt = ChatPromptTemplate.from_messages([
        ("system", '''
You are an expert data analyst tasked with analyzing SQL databases. Your goal is to interpret user questions, understand the provided schema, and identify relevant tables and columns.

Instructions:
1. Analyze the user question and database schema to identify relevant tables and columns.
2. Set "is_relevant" to false if the question is not applicable to the database or lacks sufficient information for an answer.
3. Focus on columns with meaningful nouns (e.g., names, entities) and exclude non-noun columns (e.g., IDs, numerical data) unless specifically relevant to the question.
4. Return the response in the following JSON format:
{{
  "is_relevant": boolean,
  "relevant_tables": [
    {{
      "table_name": "string",
      "columns": ["string"],
      "noun_columns": ["string"]
    }}
  ]
}}

Key Guidelines:
- Always verify column names against the provided schema.
- Include only existing schema column names in the "columns" and "noun_columns" lists.
- "noun_columns" shouldn't include any numeric value verify the type from schema, type must be not Int, Bigint or any type of integer value .
- Do not add query-mentioned values or entities to "columns" or "noun_columns" unless they are actual column names in the schema.
- Ensure "noun_columns" contains only valid column names from the schema, matching their exact format.
- Include in "noun_columns" only noun-based columns relevant to the question (e.g., "artist_name" for "Who are the top-selling artists?").
- Exclude numerical or ID columns from "noun_columns" unless they represent meaningful entities.
- If a term in the query matches a likely column value rather than a column name (e.g., "Brazil" in "matches where Brazil scored"), do not include it in the lists.

Example:
Question: "What is the total number of matches where the Brazil team scored more than 2 goals?"
- Do not include "Brazil team" in columns or noun_columns as it's likely a value, not a column name.
- Include relevant columns like "team_name", "goals_scored" if they exist in the schema.

    '''),
        ("human", "===Database Schema:\n{schema}\n\n===User Question:\n{question}\n\nIdentify the relevant tables and columns based on the provided information:")
    ])


    output_parser = JsonOutputParser()
    # Use the format method to create the formatted prompt
    formatted_prompt = prompt.format(schema=schema, question=question)
    
    # Invoke the LLM with the formatted prompt
    response = llm.invoke(formatted_prompt)
    
    extracted_json = simple_json_extraction(response.content)
    parsed_response = output_parser.parse(extracted_json)
    return {"parsed_question": parsed_response}

# %%
# parse_question = get_parse_question({"schema":schema,"question":"What is the total number of matches where the Brazil team scored more than 2 goals?"})
parse_question = get_parse_question({"schema":schema,"question":"Which product categories generate the most revenue?"})
print(parse_question)
# Out:
# {'parsed_question': {'is_relevant': True, 'relevant_tables': [{'table_name': 'olist_orders_dataset', 'columns': ['order_id', 'customer_id'], 'noun_columns': []}, {'table_name': 'olist_customers_dataset', 'columns': ['customer_id'], 'noun_columns': ['customer_city', 'customer_state']}]}}

# %%
parse_question
# Out:
# {'parsed_question': {'is_relevant': True,
#   'relevant_tables': [{'table_name': 'olist_orders_dataset',
#     'columns': ['order_id', 'customer_id'],
#     'noun_columns': []},
#    {'table_name': 'olist_customers_dataset',
#     'columns': ['customer_id'],
#     'noun_columns': ['customer_city', 'customer_state']}]}}

# %%
def get_unique_nouns(state: dict) -> dict:
    """Find unique nouns in relevant tables and columns."""
    # Extract parsed question details from the state
    parsed_question = state['parsed_question']
    
    # Return an empty dictionary if the question is not relevant
    if not parsed_question['is_relevant']:
        return {"unique_nouns": {}}

    # Initialize a dictionary to collect unique nouns segregated by table and column
    unique_nouns = {}

    # Loop through the relevant tables extracted from the parsed question
    for table_info in parsed_question['relevant_tables']:
        table_name = table_info['table_name']
        noun_columns = table_info['noun_columns']
        
        # Initialize a dictionary for the current table
        unique_nouns[table_name] = {}

        # If there are noun columns to process
        for column in noun_columns:
            # Construct the SQL query to select distinct values from the column
            query = f"SELECT DISTINCT `{column}` FROM `{table_name}`"
            
            with Session() as session:           
                result = session.execute(text(query))  # Use text() for raw SQL
                # If the query is a SELECT statement, fetch the results
                if result.returns_rows:
                    # Create a set for unique values for the current column
                    unique_values = set()
                    for row in result:
                        # Add each non-null value as a string to the unique values set
                        if row[0]:  # row[0] is the value of the column
                            unique_values.add(str(row[0]))

                    # Store the unique values in the dictionary under the respective table and column
                    unique_nouns[table_name][column] = unique_values

                else:
                    # For non-SELECT queries, commit the transaction
                    session.commit()

    # Return the unique nouns segregated by table and column
    return {"unique_nouns": unique_nouns}

# %%
unique_nouns = get_unique_nouns(parse_question)

# %%
# unique_nouns

# %% [markdown]
# ### Generate SQL Query

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", '''
    You are an AI assistant that generates SQL queries based on user questions, database schema, and unique nouns found in the relevant tables. Your goal is to generate valid SQL queries that can directly answer the user's question.

    ### Instructions:
    1. Parse the user question, identify relevant tables and columns from the schema, and generate an SQL query using the correct table and column names.
    2. Ensure the SQL query answers the question using only two or three columns in the result.
    3. If there isn't enough information to generate a query, return "NOT_ENOUGH_INFO".
    4. Always enclose table and column names in backticks (`) for SQL syntax consistency.
    5. Skip rows where any column is NULL, empty (""), or contains "N/A".
    6. Use the exact spellings of nouns from the unique nouns list, but only include nouns that match actual column names in the schema.

    Here are some examples:

    1. **What is the top selling product?**
       **Type**: Simple Aggregation  
       **Answer**: 
       ```sql
       SELECT `product_name`, SUM(`quantity`) AS `total_quantity`
       FROM `sales`
       WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL 
       AND `product_name` != "" AND `quantity` != "" 
       AND `product_name` != "N/A" AND `quantity` != "N/A" 
       GROUP BY `product_name` 
       ORDER BY `total_quantity` DESC 
       LIMIT 1```
         
    2. **What is the total revenue for each product?**
       **Type**: Revenue Calculation
       **Answer**: 
       ```sql
         SELECT `product_name`, SUM(`quantity` * `price`) AS `total_revenue`
         FROM `sales`
         WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL 
         AND `price` IS NOT NULL AND `product_name` != "" 
         AND `quantity` != "" AND `price` != "" 
         AND `product_name` != "N/A" AND `quantity` != "N/A" 
         AND `price` != "N/A"
         GROUP BY `product_name`
         ORDER BY `total_revenue` DESC
         ```

    3. **What is the market share of each product?** 
       **Type**: Market Share Calculation
       **Answer**:
       ```sql
         SELECT `product_name`, 
         SUM(`quantity`) * 100.0 / (SELECT SUM(`quantity`) FROM `sales`) AS `market_share`
         FROM `sales`
         WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL 
         AND `product_name` != "" AND `quantity` != "" 
         AND `product_name` != "N/A" AND `quantity` != "N/A"
         GROUP BY `product_name`
         ORDER BY `market_share` DESC
         ```
    4. **Which customers purchased the top-selling products?** 
       **Type**: Join Query
       **Answer**:
        ```sql
         SELECT `customers`.`customer_name`, `sales`.`product_name`, `sales`.`total_quantity`
         FROM `customers`
         JOIN `sales` ON `customers`.`customer_id` = `sales`.`customer_id`
         WHERE `sales`.`total_quantity` = (
             SELECT MAX(`total_quantity`) FROM `sales`
         )
        ```

    5. **Plot the distribution of income over time.**
       **Type**: Distribution Plot
       **Answer**:
         ```sql
         SELECT `income`, COUNT(*) AS `count`
         FROM `users`
         WHERE `income` IS NOT NULL AND `income` != "" AND `income` != "N/A"
         GROUP BY `income`
        ```

    6. **What is the total sales between 2021 and 2023?**
       **Type**: Date Range Query
       **Answer**:
         ```sql
         SELECT SUM(`quantity` * `price`) AS `total_sales`
         FROM `sales`
         WHERE `sale_date` BETWEEN '2021-01-01' AND '2023-12-31'
         ```
    7. **Find the total sales for each region, including customer count**
       **Type**: Complex Aggregation
       **Answer**:
         ```sql
         SELECT `regions`.`region_name`, SUM(`sales`.`quantity` * `sales`.`price`) AS `total_sales`, COUNT(DISTINCT `customers`.`customer_id`) AS `customer_count`
         FROM `sales`
         JOIN `customers` ON `sales`.`customer_id` = `customers`.`customer_id`
         JOIN `regions` ON `customers`.`region_id` = `regions`.`region_id`
         GROUP BY `regions`.`region_name`
         ORDER BY `total_sales` DESC
         ```
         
    ### Format for Results:
    - For simple queries (without labels): `[[x, y]]`
    - For queries with labels: `[[label, x, y]]`

    Just return the SQL query string based on the schema, question, and unique nouns provided.
    '''), 
    ("human", '''===Database schema: {schema}

    ===User question: {question}

    ===Relevant tables and columns: {relevant_table_column}
      

    Generate SQL query string:''')
])

    # ===Unique nouns in relevant tables: {unique_nouns}
    # This is the unique_noun format dont get confused with it :
    #   {
    #     "unique_nouns": {
    #         "table_name": {
    #             "column_name": {"noun1", "noun2",...},
    #             ...
    #         },
    #           "table_name": {
    #             "column_name": {"noun1", "noun2",...},
    #             ...
    #         },
    #          ...
    #     }
    # }

# %%
question = "Which product categories generate the most revenue?"
formatted_prompt = prompt.format(schema=schema, question=question, relevant_table_column=parse_question, unique_nouns=unique_nouns)

# %%
formatted_prompt
# Out:
# 'System: \n    You are an AI assistant that generates SQL queries based on user questions, database schema, and unique nouns found in the relevant tables. Your goal is to generate valid SQL queries that can directly answer the user\'s question.\n\n    ### Instructions:\n    1. Parse the user question, identify relevant tables and columns from the schema, and generate an SQL query using the correct table and column names.\n    2. Ensure the SQL query answers the question using only two or three columns in the result.\n    3. If there isn\'t enough information to generate a query, return "NOT_ENOUGH_INFO".\n    4. Always enclose table and column names in backticks (`) for SQL syntax consistency.\n    5. Skip rows where any column is NULL, empty (""), or contains "N/A".\n    6. Use the exact spellings of nouns from the unique nouns list, but only include nouns that match actual column names in the schema.\n\n    Here are some examples:\n\n    1. **What is the top selling product?**\n       **Type**: Simple Aggregation  \n       **Answer**: \n       ```sql\n       SELECT `product_name`, SUM(`quantity`) AS `total_quantity`\n       FROM `sales`\n       WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL \n       AND `product_name` != "" AND `quantity` != "" \n       AND `product_name` != "N/A" AND `quantity` != "N/A" \n       GROUP BY `product_name` \n       ORDER BY `total_quantity` DESC \n       LIMIT 1```\n         \n    2. **What is the total revenue for each product?**\n       **Type**: Revenue Calculation\n       **Answer**: \n       ```sql\n         SELECT `product_name`, SUM(`quantity` * `price`) AS `total_revenue`\n         FROM `sales`\n         WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL \n         AND `price` IS NOT NULL AND `product_name` != "" \n         AND `quantity` != "" AND `price` != "" \n         AND `product_name` != "N/A" AND `quantity` != "N/A" \n         AND `price` != "N/A"\n         GROUP BY `product_name`\n         ORDER BY `total_revenue` DESC\n         ```\n\n    3. **What is the market share of each product?** \n       **Type**: Market Share Calculation\n       **Answer**:\n       ```sql\n         SELECT `product_name`, \n         SUM(`quantity`) * 100.0 / (SELECT SUM(`quantity`) FROM `sales`) AS `market_share`\n         FROM `sales`\n         WHERE `product_name` IS NOT NULL AND `quantity` IS NOT NULL \n         AND `product_name` != "" AND `quantity` != "" \n         AND `product_name` != "N/A" AND `quantity` != "N/A"\n         GROUP BY `product_name`\n         ORDER BY `market_share` DESC\n         ```\n    4. **Which customers purchased the top-selling products?** \n       **Type**: Join Query\n       **Answer**:\n        ```sql\n         SELECT `customers`.`customer_name`, `sales`.`product_name`, `sales`.`total_quantity`\n         FROM `customers`\n         JOIN `sales` ON `customers`.`customer_id` = `sales`.`customer_id`\n         WHERE `sales`.`total_quantity` = (\n             SELECT MAX(`total_quantity`) FROM `sales`\n         )\n        ```\n\n    5. **Plot the distribution of income over time.**\n       **Type**: Distribution Plot\n       **Answer**:\n         ```sql\n         SELECT `income`, COUNT(*) AS `count`\n         FROM `users`\n         WHERE `income` IS NOT NULL AND `income` != "" AND `income` != "N/A"\n         GROUP BY `income`\n        ```\n\n    6. **What is the total sales between 2021 and 2023?**\n       **Type**: Date Range Query\n       **Answer**:\n         ```sql\n         SELECT SUM(`quantity` * `price`) AS `total_sales`\n         FROM `sales`\n         WHERE `sale_date` BETWEEN \'2021-01-01\' AND \'2023-12-31\'\n         ```\n    7. **Find the total sales for each region, including customer count**\n       **Type**: Complex Aggregation\n       **Answer**:\n         ```sql\n         SELECT `regions`.`region_name`, SUM(`sales`.`quantity` * `sales`.`price`) AS `total_sales`, COUNT(DISTINCT `customers`.`customer_id`) AS `customer_count`\n         FRO ...

# %%
def generete_sql_query():

    # output_parser = JsonOutputParser()

    chain = prompt | llm | output_parser
    # extracted_json = simple_json_extraction(response.content)
    # parsed_response = output_parser.parse(extracted_json)
    response = chain.invoke({"schema":schema, "question":question, "relevant_table_column":parse_question})
    # print(response)
    clean_sql_query = response.strip('`').replace('sql\n', '', 1).strip()
    if response.strip() == "NOT_ENOUGH_INFO":
        return {"sql_query": "NOT_RELEVANT"}
    else:
        return {"sql_query": clean_sql_query}

# %%
generated_sql_que = generete_sql_query()

# %% [markdown]
# ### Validate SQL Query

# %%
def validate_and_fix_sql(state: dict) -> dict:
    """Validate and fix the generated SQL query."""
    sql_query = state['sql_query']
    if sql_query == "NOT_RELEVANT":
        return {"sql_query": "NOT_RELEVANT", "sql_valid": False}
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", '''
    You are an AI assistant that validates and fixes SQL queries. Your task is to:
    1. Check if the SQL query is valid.
    2. Ensure all table and column names are correctly spelled and exist in the schema. All table and column names should be enclosed in backticks, especially if they contain spaces or special characters.
    3. Ensure the SQL query follows proper syntax (e.g., `JOIN`, `WHERE`, and other clauses are used correctly).
    4. Take into account case sensitivity based on the schema.
    5. If there are any issues, fix them and provide the corrected SQL query.
    6. If no issues are found, return the original query.

    Respond in JSON format with the following structure. Only respond with the JSON:
    {{
        "valid": boolean,
        "issues": string or null,
        "corrected_query": string
    }}
    '''),
        ("human", '''===Database schema:
    {schema}

    ===Generated SQL query:
    {sql_query}

    Respond in JSON format with the following structure. Only respond with the JSON:
    {{
        "valid": boolean,
        "issues": string or null,
        "corrected_query": string
    }}

    For example:
    1. {{
        "valid": true,
        "issues": null,
        "corrected_query": "None"
    }}
                
    2. {{
        "valid": false,
        "issues": "Column USERS does not exist",
        "corrected_query": "SELECT * FROM \`users\` WHERE age > 25"
    }}

    3. {{
        "valid": false,
        "issues": "Column names and table names should be enclosed in backticks if they contain spaces or special characters",
        "corrected_query": "SELECT * FROM \`gross income\` WHERE \`age\` > 25"
    }}
                
    '''),
    ])

    # prompt.format(schema=schema, sql_query=sql_query)
    output_parser = JsonOutputParser()

    chain = prompt | llm | output_parser

    result = chain.invoke({"schema":schema, "sql_query":sql_query})
    
    if result["valid"] and result["issues"] is None:
        return {"sql_query": sql_query, "sql_valid": True}
    else:
        return {
            "sql_query": result["corrected_query"],
            "sql_valid": result["valid"],
            "sql_issues": result["issues"]
        }

# %%
valid_sql_query = validate_and_fix_sql(generated_sql_que)

# %%
query_result = execute_query(valid_sql_query["sql_query"])

# %% [markdown]
# ### Get answer in sentence

# %%
def format_results(state: dict) -> dict:
    """Format query results into a human-readable response."""
    question = state['question']
    results = state['results']
    if results == "NOT_RELEVANT":
        return {"answer": "Sorry, I can only give answers relevant to the database."}
    prompt = ChatPromptTemplate.from_messages([
        ("system", '''
    You are an AI assistant that converts database query results into a clear, concise human-readable response. Your goal is to provide a brief conclusion to the user's question based on the query results. 
    Instructions:
    1. Respond in one sentence.
    2. Highlight the key result by enclosing it in double asterisks (**).
    3. Avoid using markdown or unnecessary formatting.

    '''),
        ("human", "User question: {question}\n\nQuery results: {results}\n\nConclusion:")
    ])
    chain = prompt | llm | output_parser
    response = chain.invoke({"question":question, "results":results})
    return {"answer": response}

# %%
format_results({
    "question":question, 
    "results":query_result
})
# Out:
# {'answer': 'The product category that generates the most revenue is **beleza_saude** . \n'}

# %% [markdown]
# ### Format response for visualization

# %%
def choose_visualization(state: dict) -> dict:
    """Choose an appropriate visualization for the data."""
    question = state['question']
    results = state['results']
    sql_query = state['sql_query']

    if results == "NOT_RELEVANT":
        return {"visualization": "none", "visualization_reasoning": "No visualization needed for irrelevant questions."}
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", '''
    You are an AI assistant recommending the best data visualizations. Based on the user's question, SQL query, and query results, suggest the most suitable graph or chart type.

    ### Chart Types:
    - **Bar Graph**: For comparing categorical data or showing changes over time with more than two categories.
    - **Horizontal Bar Graph**: For comparing few categories or when there's a large disparity between them.
    - **Scatter Plot**: For showing relationships or distributions between two continuous numerical variables.
    - **Pie Chart**: For displaying proportions or percentages of a whole.
    - **Line Graph**: For showing trends over time, where both x and y axes are continuous.
    - **None**: If no visualization is appropriate.

    ### Consider These Questions:
    1. **Aggregations**: Summarize data (e.g., average revenue by month) — Line Graph.
    2. **Comparisons**: Compare metrics (e.g., sales of Product A vs. Product B) — Line or Bar Graph.
    3. **Distributions**: Show data distribution (e.g., age distribution) — Scatter Plot.
    4. **Trends Over Time**: Show changes over time (e.g., website visits) — Line Graph.
    5. **Proportions**: Show percentages (e.g., market share) — Pie Chart.
    6. **Correlations**: Show relationships (e.g., marketing spend vs. revenue) — Scatter Plot.

    ### Format:
         {{
            recommended_visualization: string (bar | horizontal_bar | line | pie | scatter | none),
            reason: Brief explanation of your recommendation
         }}
    '''),
        ("human", '''
    User question: {question}
    SQL query: {sql_query}
    Query results: {results}

    Recommend a visualization:
        '''),
    ])

    output_parser = JsonOutputParser()

    chain = prompt | llm | output_parser

    response = chain.invoke({"question":question,"sql_query":sql_query,"results":results})

    return response

# %%
choose_visualization({
    "question":question, 
    "results":query_result,
    "sql_query":valid_sql_query
})
# Out:
# {'recommended_visualization': 'bar',
#  'reason': 'The query results show product categories and their total revenue. A bar graph is suitable for comparing categorical data (product categories) using the revenue as the value.'}
